# %% [markdown]
# <a href="https://colab.research.google.com/github/bcury/Machine-Learning-Projects/blob/main/AI_gen_PGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Definir GPU!

# %%
import torch
import matplotlib.pyplot as plt
import torchvision

# %%
use_gpu = True if torch.cuda.is_available() else False
total_images = 4

model = torch.hub.load('facebookresearch/pytorch_GAN_zoo:hub','PGAN', model_name='celebAHQ-512', pretrained=True, useGPU=use_gpu)
# Out:
# Downloading: "https://github.com/facebookresearch/pytorch_GAN_zoo/zipball/hub" to /root/.cache/torch/hub/hub.zip
# Downloading: "https://dl.fbaipublicfiles.com/gan_zoo/PGAN/celebaHQ16_december_s7_i96000-9c72988c.pth" to /root/.cache/torch/hub/checkpoints/celebaHQ16_december_s7_i96000-9c72988c.pth
# 100%|██████████| 264M/264M [00:01<00:00, 215MB/s]
# Average network found !

# %%
noise, _ = model.buildNoiseData(total_images)

with torch.no_grad():
    images = model.test(noise)

# %%
plt.imshow(torchvision.utils.make_grid(images.clamp(min=-1, max=1), scale_each=True, normalize=True).permute(1, 2, 0).cpu().numpy())
plt.axis('off')
plt.show()
